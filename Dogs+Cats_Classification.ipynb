# %% [markdown]
# <a href="https://colab.research.google.com/github/SophieShin/DeepLearning/blob/main/Dogs%2BCats_Classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !wget --no-check-certificate \
https://storage.googleapis.com/mledu-datasets/cats_and_dogs_filtered.zip \
-O /tmp/cats_and_dogs_filtered.zip
# Out:
# --2021-09-29 07:31:25--  https://storage.googleapis.com/mledu-datasets/cats_and_dogs_filtered.zip
# Resolving storage.googleapis.com (storage.googleapis.com)... 172.217.214.128, 172.253.114.128, 108.177.121.128, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|172.217.214.128|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 68606236 (65M) [application/zip]
# Saving to: ‘/tmp/cats_and_dogs_filtered.zip’
#
# /tmp/cats_and_dogs_ 100%[===================>]  65.43M   179MB/s    in 0.4s
#
# 2021-09-29 07:31:25 (179 MB/s) - ‘/tmp/cats_and_dogs_filtered.zip’ saved [68606236/68606236]

# %%
import os
import zipfile

local_zip = '/tmp/cats_and_dogs_filtered.zip'

zip_ref = zipfile.ZipFile(local_zip, 'r')

zip_ref.extractall('/tmp')
zip_ref.close()

# %%
# 기본 경로
base_dir = '/tmp/cats_and_dogs_filtered'

train_dir = os.path.join(base_dir, 'train')
validation_dir = os.path.join(base_dir, 'validation')

# 훈련에 사용되는 고양이/개 이미지 경로
train_cats_dir = os.path.join(train_dir, 'cats')
train_dogs_dir = os.path.join(train_dir, 'dogs')
print(train_cats_dir)
print(train_dogs_dir)

# 테스트에 사용되는 고양이/개 이미지 경로
validation_cats_dir = os.path.join(validation_dir, 'cats')
validation_dogs_dir = os.path.join(validation_dir, 'dogs')
print(validation_cats_dir)
print(validation_dogs_dir)
# Out:
# /tmp/cats_and_dogs_filtered/train/cats
# /tmp/cats_and_dogs_filtered/train/dogs
# /tmp/cats_and_dogs_filtered/validation/cats
# /tmp/cats_and_dogs_filtered/validation/dogs

# %%
train_cat_fnames = os.listdir( train_cats_dir )
train_dog_fnames = os.listdir( train_dogs_dir )

print(train_cat_fnames[:5])
print(train_dog_fnames[:5])
# Out:
# ['cat.512.jpg', 'cat.942.jpg', 'cat.361.jpg', 'cat.655.jpg', 'cat.796.jpg']
# ['dog.56.jpg', 'dog.567.jpg', 'dog.290.jpg', 'dog.779.jpg', 'dog.123.jpg']

# %%
print('Total training cat images :', len(os.listdir(train_cats_dir)))
print('Total training dog images :', len(os.listdir(train_dogs_dir)))

print('Total validation cat images :', len(os.listdir(validation_cats_dir)))
print('Total validation dog images :', len(os.listdir(validation_dogs_dir)))
# Out:
# Total training cat images : 1000
# Total training dog images : 1000
# Total validation cat images : 500
# Total validation dog images : 500

# %%
# %matplotlib inline

import matplotlib.image as mpimg
import matplotlib.pyplot as plt

nrows, ncols = 4, 4
pic_index = 0

fig = plt.gcf()
fig.set_size_inches(ncols*3, nrows*3)

pic_index+=8

next_cat_pix = [os.path.join(train_cats_dir, fname)
                for fname in train_cat_fnames[ pic_index-8:pic_index]]

next_dog_pix = [os.path.join(train_dogs_dir, fname)
                for fname in train_dog_fnames[ pic_index-8:pic_index]]

for i, img_path in enumerate(next_cat_pix+next_dog_pix):
  sp = plt.subplot(nrows, ncols, i + 1)
  sp.axis('Off')

  img = mpimg.imread(img_path)
  plt.imshow(img)

plt.show()

# %%
import tensorflow as tf


model = tf.keras.models.Sequential([
  tf.keras.layers.Conv2D(16, (3,3), activation='relu', input_shape=(150, 150, 3)),
  tf.keras.layers.MaxPooling2D(2,2),
  tf.keras.layers.Conv2D(32, (3,3), activation='relu'),
  tf.keras.layers.MaxPooling2D(2,2),
  tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
  tf.keras.layers.MaxPooling2D(2,2),
  tf.keras.layers.Flatten(),
  tf.keras.layers.Dense(512, activation='relu'),
  tf.keras.layers.Dense(1, activation='sigmoid')
])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 148, 148, 16)      448
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 74, 74, 16)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 72, 72, 32)        4640
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 36, 36, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 34, 34, 64)        18496
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 17, 17, 64)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 18496)             0
# _________________________________________________________________
# dense (Dense)                (None, 512)               9470464
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 513
# =================================================================
# Total params: 9,494,561
# Trainable params: 9,494,561
# Non-trainable params: 0
# _________________________________________________________________

# %%
from tensorflow.keras.optimizers import RMSprop

model.compile(optimizer=RMSprop(lr=0.001),
            loss='binary_crossentropy',
            metrics = ['accuracy'])
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/optimizer_v2.py:356: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   "The `lr` argument is deprecated, use `learning_rate` instead.")

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator


train_datagen = ImageDataGenerator( rescale = 1.0/255. )
test_datagen  = ImageDataGenerator( rescale = 1.0/255. )

train_generator = train_datagen.flow_from_directory(train_dir,
                                                  batch_size=20,
                                                  class_mode='binary',
                                                  target_size=(150, 150))
validation_generator =  test_datagen.flow_from_directory(validation_dir,
                                                       batch_size=20,
                                                       class_mode  = 'binary',
                                                       target_size = (150, 150))
# Out:
# Found 2000 images belonging to 2 classes.
# Found 1000 images belonging to 2 classes.

# %%
history = model.fit(train_generator,
                    validation_data=validation_generator,
                    steps_per_epoch=100,
                    epochs=100,
                    validation_steps=50,
                    verbose=2)
# Out:
# Epoch 1/100
# 100/100 - 42s - loss: 0.7585 - accuracy: 0.5325 - val_loss: 0.6581 - val_accuracy: 0.6690
# Epoch 2/100
# 100/100 - 10s - loss: 0.6374 - accuracy: 0.6515 - val_loss: 0.5929 - val_accuracy: 0.7000
# Epoch 3/100
# 100/100 - 10s - loss: 0.5403 - accuracy: 0.7395 - val_loss: 0.6150 - val_accuracy: 0.6620
# Epoch 4/100
# 100/100 - 9s - loss: 0.4511 - accuracy: 0.7925 - val_loss: 0.5526 - val_accuracy: 0.7440
# Epoch 5/100
# 100/100 - 10s - loss: 0.3664 - accuracy: 0.8430 - val_loss: 0.6376 - val_accuracy: 0.7240
# Epoch 6/100
# 100/100 - 9s - loss: 0.2859 - accuracy: 0.8770 - val_loss: 0.7851 - val_accuracy: 0.7060
# Epoch 7/100
# 100/100 - 10s - loss: 0.1987 - accuracy: 0.9235 - val_loss: 0.7915 - val_accuracy: 0.7190
# Epoch 8/100
# 100/100 - 10s - loss: 0.1296 - accuracy: 0.9535 - val_loss: 1.7818 - val_accuracy: 0.5860
# Epoch 9/100
# 100/100 - 10s - loss: 0.0804 - accuracy: 0.9720 - val_loss: 1.1304 - val_accuracy: 0.7350
# Epoch 10/100
# 100/100 - 10s - loss: 0.0990 - accuracy: 0.9750 - val_loss: 1.1512 - val_accuracy: 0.7340
# Epoch 11/100
# 100/100 - 10s - loss: 0.0332 - accuracy: 0.9875 - val_loss: 1.3578 - val_accuracy: 0.7280
# Epoch 12/100
# 100/100 - 10s - loss: 0.0526 - accuracy: 0.9895 - val_loss: 1.6589 - val_accuracy: 0.7290
# Epoch 13/100
# 100/100 - 10s - loss: 0.0313 - accuracy: 0.9885 - val_loss: 1.7224 - val_accuracy: 0.7220
# Epoch 14/100
# 100/100 - 10s - loss: 0.0860 - accuracy: 0.9920 - val_loss: 2.0474 - val_accuracy: 0.7230
# Epoch 15/100
# 100/100 - 10s - loss: 0.0247 - accuracy: 0.9945 - val_loss: 2.0184 - val_accuracy: 0.7280
# Epoch 16/100
# 100/100 - 9s - loss: 0.0246 - accuracy: 0.9930 - val_loss: 2.3301 - val_accuracy: 0.7220
# Epoch 17/100
# 100/100 - 9s - loss: 0.0429 - accuracy: 0.9905 - val_loss: 2.1033 - val_accuracy: 0.7120
# Epoch 18/100
# 100/100 - 9s - loss: 0.0343 - accuracy: 0.9905 - val_loss: 3.4972 - val_accuracy: 0.6260
# Epoch 19/100
# 100/100 - 9s - loss: 0.0387 - accuracy: 0.9930 - val_loss: 1.9683 - val_accuracy: 0.7000
# Epoch 20/100
# 100/100 - 9s - loss: 0.0169 - accuracy: 0.9950 - val_loss: 2.6149 - val_accuracy: 0.7030
# Epoch 21/100
# 100/100 - 9s - loss: 0.0128 - accuracy: 0.9955 - val_loss: 2.6774 - val_accuracy: 0.7170
# Epoch 22/100
# 100/100 - 9s - loss: 0.0722 - accuracy: 0.9915 - val_loss: 2.7764 - val_accuracy: 0.7160
# Epoch 23/100
# 100/100 - 10s - loss: 2.5649e-04 - accuracy: 1.0000 - val_loss: 3.0329 - val_accuracy: 0.7230
# Epoch 24/100
# 100/100 - 10s - loss: 0.0456 - accuracy: 0.9920 - val_loss: 2.6374 - val_accuracy: 0.7210
# Epoch 25/100
# 100/100 - 10s - loss: 0.0065 - accuracy: 0.9970 - val_loss: 2.9444 - val_accuracy: 0.7070
# Epoch 26/100
# 100/100 - 10s - loss: 0.0330 - accuracy: 0.9910 - val_loss: 2.9226 - val_accuracy: 0.7030
# Epoch 27/100
# 100/100 - 9s - loss: 0.0188 - accuracy: 0.9970 - val_loss: 3.5178 - val_accuracy: 0.7040
# Epoch 28/100
# 100/100 - 10s - loss: 0.0048 - accuracy: 0.9980 - val_loss: 3.3125 - val_accuracy: 0.7260
# Epoch 29/100
# 100/100 - 10s - loss: 0.0366 - accuracy: 0.9940 - val_loss: 3.0230 - val_accuracy: 0.7320
# Epoch 30/100
# 100/100 - 10s - loss: 0.0212 - accuracy: 0.9970 - val_loss: 2.9842 - val_accuracy: 0.7150
# Epoch 31/100
# 100/100 - 10s - loss: 2.8218e-05 - accuracy: 1.0000 - val_loss: 3.4016 - val_accuracy: 0.7210
# Epoch 32/100
# 100/100 - 10s - loss: 0.0256 - accuracy: 0.9970 - val_loss: 4.0003 - val_accuracy: 0.7240
# Epoch 33/100
# 100/100 - 10s - loss: 0.0226 - accuracy: 0.9935 - val_loss: 2.9087 - val_accuracy: 0.7380
# Epoch 34/100
# 100/100 - 10s - loss: 0.0236 - accuracy: 0.9965 - val_loss: 4.3136 - val_accuracy: 0.7280
# Epoch 35/100
# 100/100 - 10s - loss: 0.0233 - accuracy: 0.9920 - val_loss: 3.5109 - val_accuracy: 0.7200
# Epoch 36/100
# 100/100 - 10s - loss: 0.0093 - accuracy: 0.9985 - val_loss: 3.8502 - val_accuracy: 0.7360
# Epoch 37/100
# 100/100 - 10s - loss: 0.0335 - accuracy: 0.9910 - val_loss: 3.4146 - val_accuracy: 0.7240
# Epoch 38/100
# 100/100 - 10s - loss: 0.0204 - accuracy: 0.9965 - val_loss: 3.4244 - val_accuracy: 0.7150
# Epoch 39/100
# 100/100 - 10s - loss: 0.0082 - accuracy: 0.9990 - val_loss: 3.2933 - val_accuracy: 0.7280
# Epoch 40/100
# 100/100 - 10s - loss: 2.1468e-04 - accuracy: 1.0000 - val_loss: 3.7457 - val_accuracy: 0.7470
# Epoch 41/100
# 100/100 - 10s - loss: 0.0034 - accuracy: 0.9990 - val_loss: 4.9295 - val_accuracy: 0.7070
# Epoch 42/100
# 100/100 - 10s - loss: 0.0148 - accuracy: 0.9975 - val_loss: 4.3583 - val_accuracy: 0.7280
# Epoch 43/100
# 100/100 - 10s - loss: 0.0036 - accuracy: 0.9985 - val_loss: 4.4907 - val_accuracy: 0.7190
# Epoch 44/100
# 100/100 - 10s - loss: 2.6697e-04 - accuracy: 1.0000 - val_loss: 4.7202 - val_accuracy: 0.7310
# Epoch 45/100
# 100/100 - 9s - loss: 0.0227 - accuracy: 0.9945 - val_loss: 4.0774 - val_accuracy: 0.7270
# Epoch 46/100
# 100/100 - 10s - loss: 0.0320 - accuracy: 0.9945 - val_loss: 4.5083 - val_accuracy: 0.7130
# Epoch 47/100
# 100/100 - 10s - loss: 0.0182 - accuracy: 0.9970 - val_loss: 3.9119 - val_accuracy: 0.7090
# Epoch 48/100
# 100/100 - 10s - loss: 0.0186 - accuracy: 0.9975 - val_loss: 7.0585 - val_accuracy: 0.6800
# Epoch 49/100
# 100/100 - 10s - loss: 0.0038 - accuracy: 0.9985 - val_loss: 4.9186 - val_accuracy: 0.7280
# Epoch 50/100
# 100/100 - 10s - loss: 0.0024 - accuracy: 0.9990 - val_loss: 4.6783 - val_accuracy: 0.7040
# Epoch 51/100
# 100/100 - 10s - loss: 0.0617 - accuracy: 0.9935 - val_loss: 4.8170 - val_accuracy: 0.7100
# Epoch 52/100
# 100/100 - 10s - loss: 2.8285e-06 - accuracy: 1.0000 - val_loss: 4.6731 - val_accuracy: 0.7120
# Epoch 53/100
# 100/100 - 10s - loss: 2.6555e-07 - accuracy: 1.0000 - val_loss: 4.9839 - val_accuracy: 0.7190
# Epoch 54/100
# 100/100 - 10s - loss: 3.8969e-09 - accuracy: 1.0000 - val_loss: 5.3445 - val_accuracy: 0.7220
# Epoch 55/100
# 100/100 - 10s - loss: 1.0365e-09 - accuracy: 1.0000 - val_loss: 5.5550 - val_accuracy: 0.7220
# Epoch 56/100
# 100/100 - 10s - loss: 9.1948e-10 - accuracy: 1.0000 - val_loss: 5.7584 - val_accuracy: 0.7250
# Epoch 57/100
# 100/100 - 10s - loss: 1.7666e-10 - accuracy: 1.0000 - val_loss: 5.7695 - val_accuracy: 0.7280
# Epoch 58/100
# 100/100 - 10s - loss: 1.7961e-10 - accuracy: 1.0000 - val_loss: 5.7497 - val_accuracy: 0.7220
# Epoch 59/100
# 100/100 - 10s - loss: 1.2580e-10 - accuracy: 1.0000 - val_loss: 5.7598 - val_accuracy: 0.7260
# Epoch 60/100
# 100/100 - 10s - loss: 1.2779e-10 - accuracy: 1.0000 - val_loss: 5.7884 - val_accuracy: 0.7240
# Epoch 61/100
# 100/100 - 10s - loss: 9.7147e-11 - accuracy: 1.0000 - val_loss: 5.7993 - val_accuracy: 0.7260
# Epoch 62/100
# 100/100 - 10s - loss: 1.1088e-10 - accuracy: 1.0000 - val_loss: 5.8030 - val_accuracy: 0.7260
# Epoch 63/100
# 100/100 - 10s - loss: 1.1769e-10 - accuracy: 1.0000 - val_loss: 5.8079 - val_accuracy: 0.7280
# Epoch 64/100
# 100/100 - 10s - loss: 1.2888e-10 - accuracy: 1.0000 - val_loss: 5.8142 - val_accuracy: 0.7260
# Epoch 65/100
# 100/100 - 9s - loss: 1.4102e-10 - accuracy: 1.0000 - val_loss: 5.8201 - val_accuracy: 0.7260
# Epoch 66/100
# 100/100 - 9s - loss: 1.4749e-10 - accuracy: 1.0000 - val_loss: 5.8230 - val_accuracy: 0.7270
# Epoch 67/100
# 100/100 - 10s - loss: 1.5913e-10 - accuracy: 1.0000 - val_loss: 5.8265 - val_accuracy: 0.7270
# Epoch 68/100
# 100/100 - 10s - loss: 1.6915e-10 - accuracy: 1.0000 - val_loss: 5.8302 - val_accuracy: 0.7270
# Epoch 69/100
# 100/100 - 10s - loss: 1.3655e-10 - accuracy: 1.0000 - val_loss: 5.8243 - val_accuracy: 0.7260
# Epoch 70/100
# 100/100 - 10s - loss: 1.0390e-10 - accuracy: 1.0000 - val_loss: 5.8293 - val_accuracy: 0.7260
# Epoch 71/100
# 100/100 - 10s - loss: 1.1273e-10 - accuracy: 1.0000 - val_loss: 5.8333 - val_accuracy: 0.7270
# Epoch 72/100
# 100/100 - 9s - loss: 1.1773e-10 - accuracy: 1.0000 - val_loss: 5.8373 - val_accuracy: 0.7260
# Epoch 73/100
# 100/100 - 9s - loss: 1.2561e-10 - accuracy: 1.0000 - val_loss: 5.8418 - val_accuracy: 0.7260
# Epoch 74/100
# 100/100 - 9s - loss: 1.2885e-10 - accuracy: 1.0000 - val_loss: 5.8163 - val_accuracy: 0.7260
# Epoch 75/100
# 100/100 - 9s - loss: 8.8140e-11 - accuracy: 1.0000 - val_loss: 5.8276 - val_accuracy: 0.7270
# Epoch 76/100
# 100/100 - 9s - loss: 9.3322e-11 - accuracy: 1.0000 - val_loss: 5.8350 - val_accuracy: 0.7270
# Epoch 77/100
# 100/100 - 9s - loss: 9.9559e-11 - accuracy: 1.0000 - val_loss: 5.8417 - val_accuracy: 0.7250
# Epoch 78/100
# 100/100 - 9s - loss: 1.0360e-10 - accuracy: 1.0000 - val_loss: 5.8466 - val_accuracy: 0.7250
# Epoch 79/100
# 100/100 - 10s - loss: 1.0142e-10 - accuracy: 1.0000 - val_loss: 5.8255 - val_accuracy: 0.7230
# Epoch 80/100
# 100/100 - 10s - loss: 7.6071e-11 - accuracy: 1.0000 - val_loss: 5.8358 - val_accuracy: 0.7230
# Epoch 81/100
# 100/100 - 10s - loss: 7.8183e-11 - accuracy: 1.0000 - val_loss: 5.8440 - val_accuracy: 0.7230
# Epoch 82/100
# 100/100 - 10s - loss: 8.1794e-11 - accuracy: 1.0000 - val_loss: 5.8502 - val_accuracy: 0.7240
# Epoch 83/100
# 100/100 - 10s - loss: 8.5622e-11 - accuracy: 1.0000 - val_loss: 5.8551 - val_accuracy: 0.7240
# Epoch 84/100
# 100/100 - 10s - loss: 9.0776e-11 - accuracy: 1.0000 - val_loss: 5.8602 - val_accuracy: 0.7250
# Epoch 85/100
# 100/100 - 10s - loss: 9.5611e-11 - accuracy: 1.0000 - val_loss: 5.8646 - val_accuracy: 0.7250
# Epoch 86/100
# 100/100 - 10s - loss: 1.0026e-10 - accuracy: 1.0000 - val_loss: 5.8688 - val_accuracy: 0.7260
# Epoch 87/100
# 100/100 - 10s - loss: 1.0286e-10 - accuracy: 1.0000 - val_loss: 5.8724 - val_accuracy: 0.7250
# Epoch 88/100
# 100/100 - 10s - loss: 1.0777e-10 - accuracy: 1.0000 - val_loss: 5.8761 - val_accuracy: 0.7250
# Epoch 89/100
# 100/100 - 10s - loss: 1.1278e-10 - accuracy: 1.0000 - val_loss: 5.8794 - val_accuracy: 0.7250
# Epoch 90/100
# 100/100 - 9s - loss: 1.1756e-10 - accuracy: 1.0000 - val_loss: 5.8827 - val_accuracy: 0.7270
# Epoch 91/100
# 100/100 - 9s - loss: 1.2246e-10 - accuracy: 1.0000 - val_loss: 5.8859 - val_accuracy: 0.7270
# Epoch 92/100
# 100/100 - 9s - loss: 1.2585e-10 - accuracy: 1.0000 - val_loss: 5.8891 - val_accuracy: 0.7260
# Epoch 93/100
# 100/100 - 10s - loss: 1.3035e-10 - accuracy: 1.0000 - val_loss: 5.8920 - val_accuracy: 0.7260
# Epoch 94/100
# 100/100 - 10s - loss: 1.1144e-10 - accuracy: 1.0000 - val_loss: 5.9655 - val_accuracy: 0.7260
# Epoch 95/100
# 100/100 - 10s - loss: 8.2498e-11 - accuracy: 1.0000 - val_loss: 5.9614 - val_accuracy: 0.7260
# Epoch 96/100
# 100/100 - 10s - loss: 8.1561e-11 - accuracy: 1.0000 - val_loss: 5.9589 - val_accuracy: 0.7260
# Epoch 97/100
# 100/100 - 9s - loss: 8.2953e-11 - accuracy: 1.0000 - val_loss: 5.9576 - val_accuracy: 0.7260
# Epoch 98/100
# 100/100 - 10s - loss: 8.4858e-11 - accuracy: 1.0000 - val_loss: 5.9564 - val_accuracy: 0.7270
# Epoch 99/100
# 100/100 - 9s - loss: 8.7452e-11 - accuracy: 1.0000 - val_loss: 5.9557 - val_accuracy: 0.7270
# Epoch 100/100
# 100/100 - 10s - loss: 8.8631e-11 - accuracy: 1.0000 - val_loss: 5.9555 - val_accuracy: 0.7280

# %%
import matplotlib.pyplot as plt

acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(len(acc))

plt.plot(epochs, acc, 'bo', label='Training accuracy')
plt.plot(epochs, val_acc, 'b', label='Validation accuracy')
plt.title('Training and validation accuracy')
plt.legend()

plt.figure()

plt.plot(epochs, loss, 'go', label='Training Loss')
plt.plot(epochs, val_loss, 'g', label='Validation Loss')
plt.title('Training and validation loss')
plt.legend()

plt.show()

# %%
import numpy as np
from google.colab import files
from keras.preprocessing import image

uploaded=files.upload()

for fn in uploaded.keys():

  path='/content/' + fn
  img=image.load_img(path, target_size=(150, 150))

  x=image.img_to_array(img)
  x=np.expand_dims(x, axis=0)
  images = np.vstack([x])

  classes = model.predict(images, batch_size=10)

  print(classes[0])

  if classes[0]>0:
    print(fn + " is a dog")
  else:
    print(fn + " is a cat")
# Out:
#      <input type="file" id="files-a4f566be-954f-48cd-aa17-0d6049ca6ee1" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a4f566be-954f-48cd-aa17-0d6049ca6ee1">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving classifying_the_cats_and_dogs_09.png to classifying_the_cats_and_dogs_09.png
# [1.]
# classifying_the_cats_and_dogs_09.png is a dog
